# %% [markdown]
# OOPS: its a solution based process where to solve a problem first all the requirements above the problem are detailed mentioned and are solved

# %% [markdown]
# class
#
#     attribtes + behaviours
#
#     attributes(properties -> identifiers):
#
#         class attributes
#
#         instance attributes
#
#     behaviours(methods -> functions):
#
#         instance behaviours
#
#         class behaviours
#
#         static behaviours
#
# object
#
# inheritance
#
#     parents/base/super -> giver
#
#     child / derived/sub -> taker
#
#     types:
#
#         single level
#
#         multi level
#
#         multiple
#
#         hyrarchical
#
#         hybrid
#
# polymorphism:
#
#     samething diff meaning in diff places
#
#     types:
#
#         method overloading #not suppoted in built
#
#         method overriding
#
#         ducktyping
#
#         opertor overriding (magic methods/dunder method)
#
#
#
# encapsulation
#
#     var - public
#
#     _var - protected
#
#     __var - private
#
# abstraction
#
#     ABC, abstract method

# %%
class cse:
  def __init__(self,name,roll_number,sub1,sub2,sub3):
    self.name = name
    self.roll_no = roll_number
    self.sub1 = sub1
    self.sub2 = sub2
    self.sub3 = sub3
  def student(self):
    print(self.name,self.roll_no)
  def crt(self):
    print(f"hi {self.name} your roll no is {self.roll_no}")
  def sports(self):
    print("sports")
  def student_marks(self):
    print(f"{self.name} your total marks are")
    print(self.sub1+self.sub2+self.sub3)
marks = cse("sathwik",1780,80,90,80)
marks1 = cse("srikar",1780,90,90,80)
group2batch3 = cse("Sathwik",1780,80,90,80)
group1batch4 = cse("Srikar",1772,80,90,80)
group2batch3.student()
group2batch3.crt()
group1batch4.student()
group1batch4.crt()
marks.student_marks()
marks1.student_marks()
# Out:
# Sathwik 1780
# hi Sathwik your roll no is 1780
# Srikar 1772
# hi Srikar your roll no is 1772
# sathwik your total marks are
# 250
# srikar your total marks are
# 260

# %% [markdown]
# 4 types of functions
# 1.with parameter and with return
# 2.with parameters and without return
# 3.without parameter and with return
# 4.without  ||                  ||

# %%
#1.
def addition(a, b, c):
  return a+b+c
addition(4,5,6)
# Out:
# 15

# %%
#1.
def addition(*variable):
  total = 0
  for i in variable:
    total += i
  return total
addition(10,20,30)
# Out:
# 60

# %%
def addition(a,**kwargs):
  s = 0
  for val in kwargs.values():
    s += val
  return s
print(addition(40,b=20,c=30))
# Out:
# 50

# %% [markdown]
# 1.print the prime numbers and perfect numbers 1to100
# 2.greatest prime factor

# %%
class ATM:
    def __init__(self, balance=0):
        self.balance = balance
    def deposit(self, amount):
        if amount > 0:
            self.balance += amount
            print(f"Deposited {amount}. New balance is {self.balance}.")
        else:
            print("Deposit amount must be positive.")
    def withdraw(self, amount):
        if amount > self.balance:
            print("Insufficient balance.")
        elif amount <= 0:
            print("Withdrawal amount must be positive.")
        else:
            self.balance -= amount
            print(f"Withdrew {amount}. New balance is {self.balance}.")
    def check_balance(self):
        print(f"Your balance is {self.balance}.")
        return self.balance
obj = ATM(10000)
obj.deposit(1000)
obj.withdraw(5000)
obj.check_balance()
# Out:
# Deposited 1000. New balance is 11000.
# Withdrew 5000. New balance is 6000.
# Your balance is 6000.
# 6000

# %% [markdown]
# Inheritance

# %%
class college:
  def library(self):
    print("access books")
class games:
  def playing(self):
    print("students are playing")
class student(college,games):
  def study(self):
    print("reading")
s1 = student()
s1.study()
s1.library()
s1.playing()
# Out:
# reading
# access books
# students are playing

# %%
class livingbeing:
  def breathing(self):
    print("breathing")
class Human(livingbeing):
  def read(self):
    print("reading")
class Humanchild(Human):
  def crying(self):
    print("crying")
s2 = Humanchild()
s2.breathing()
s2.read()
s2.crying()
# Out:
# breathing
# reading
# crying

# %%
class Company:
  def Rules(self):
    print("follow the rules")
class HR(Company):
  def Hiring(self):
    print("hiring the employees")
class frontend(Company):
  def Designing(self):
    print("designing the websites")
class backend(Company):
  def Datacollection(self):
    print("collecting the data")
hr = HR()
hr.Rules()
hr.Hiring()
fr = frontend()
fr.Rules()
fr.Designing()
bk = backend()
bk.Rules()
bk.Datacollection()
# Out:
# follow the rules
# hiring the employees
# follow the rules
# designing the websites
# follow the rules
# collecting the data

# %%
class person:
  def walk(self):
    print("walking")
class employee(person):
  def work(self):
    print("working")
class traveling:
  def travel(self):
    print("traveling")
class workingstudent(traveling,employee):
  def studying(self):
    print("studying")
s1 = workingstudent()
s1.walk()
s1.work()
s1.studying()
s1.travel()
# Out:
# walking
# working
# studying
# traveling

# %% [markdown]
# Abstraction

# %%
from abc import ABC, abstractmethod
# Abstract class
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass
    
    @abstractmethod
    def perimeter(self):
        pass
# Circle class
class Circle(Shape):
    def __init__(self, r):
        self.r = r
    
    def area(self):
        return 3.14 * self.r * self.r
    
    def perimeter(self):
        return 2 * 3.14 * self.r
# Square class
class Square(Shape):
    def __init__(self, l):
        self.l = l
    def area(self):
        return self.l * self.l
    def perimeter(self):
        return 4 * self.l

# Testing the classes
c = Circle(5)
s = Square(4)
print("Circle Area:", c.area())
print("Circle Perimeter:", c.perimeter())
print("Square Area:", s.area())
print("Square Perimeter:", s.perimeter())
# Out:
# Circle Area: 78.5
# Circle Perimeter: 31.400000000000002
# Square Area: 16
# Square Perimeter: 16

# %% [markdown]
# convert 24-hour format into 12-hour fromat user input:hours min, and am to pm
# read a number and check whetehe it is two digit or not
# a number even and divisible by 3
# read a character and check whether it is alphabet digit or special character
# read the month number and display number of days of month
# calculator program
# read numbers
# tack the cp and sp and calculate profit,loss,no loss
# read coefficients of quadratic equation and determine the nature of roots
# input age gender and martal status and determin insurence eligibility
# read temp and display freezing cold moderate hot very cold
# read time in 24hours and convert it to am 12 hours format with am/pm
# ip:salary calculate gross salary based hra and da conditions
